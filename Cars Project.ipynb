# %% [markdown]
# # Project on Car Dataset

# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("cars.csv")

# %%
cars
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
cars['Dimensions.Height'].dtype
# Out:
# dtype('int64')

# %%
cars.shape
# Out:
# (5076, 18)

# %% [markdown]
# Question 1)
#
# - find all the null vaues in the dataset if there is any null value in any column then fill it with the mean of that column

# %%
cars.isnull().sum()
# Out:
# Dimensions.Height                                  0
# Dimensions.Length                                  0
# Dimensions.Width                                   0
# Engine Information.Driveline                       0
# Engine Information.Engine Type                     0
# Engine Information.Hybrid                          0
# Engine Information.Number of Forward Gears         0
# Engine Information.Transmission                    0
# Fuel Information.City mpg                          0
# Fuel Information.Fuel Type                         0
# Fuel Information.Highway mpg                       0
# Identification.Classification                      0
# Identification.ID                                  0
# Identification.Make                                0
# Identification.Model Year                          0
# Identification.Year                                0
# Engine Information.Engine Statistics.Horsepower    0
# Engine Information.Engine Statistics.Torque        0
# ...

# %% [markdown]
# Question 2) (Based on value counts)
#
# - check what are the different types of Makes are there in our dataset and what is the count of each Make in make in the data

# %%
cars['Identification.Make'].value_counts()
# Out:
# Chevrolet             626
# Ford                  603
# GMC                   368
# Toyota                325
# Nissan                294
# Dodge                 260
# Honda                 200
# Cadillac              200
# Hyundai               188
# Mazda                 168
# Kia                   135
# BMW                   133
# Volkswagen            129
# Jeep                  119
# Subaru                105
# Volvo                 103
# Audi                   87
# Infiniti               85
# Buick                  71
# Mercedes               64
# MINI                   62
# Saab                   59
# BMW Motorrad           58
# Lexus                  52
# Suzuki                 51
# Porsche                51
# Mitsubishi             51
# Grand Cherokee         48
# Jaguar                 44
# Lincoln                43
# Aston Martin           43
# Land Rover             35
# Acura                  33
# Chrysler               30
# Mercury                28
# ...

# %% [markdown]
# Question 3)
#
# - Show all the different types of Makes are there in list format in our dataset and also show show in ascending order sorted manner.

# %%
# A list of all types of makes

cars['Identification.Make'].value_counts().unique()
# Out:
# array([626, 603, 368, 325, 294, 260, 200, 188, 168, 135, 133, 129, 119,
#        105, 103,  87,  85,  71,  64,  62,  59,  58,  52,  51,  48,  44,
#         43,  35,  33,  30,  28,  26,  18,  13,  12,  11,  10,   7,   6,
#          5,   1], dtype=int64)

# %%
#Sorted in ascending order
cars['Identification.Make'].value_counts().sort_values()
# Out:
# Ferrari                 1
# Lamborghini             5
# Mercedes-AMG            6
# Chrysler Group LLC      6
# Mercedes-Benz           7
# AMG                    10
# Rolls-Royce            10
# Lotus                  11
# Maserati               12
# Maybach                13
# Bentley                18
# Scion                  26
# Mercury                28
# Chrysler               30
# Acura                  33
# Land Rover             35
# Aston Martin           43
# Lincoln                43
# Jaguar                 44
# Grand Cherokee         48
# Mitsubishi             51
# Porsche                51
# Suzuki                 51
# Lexus                  52
# BMW Motorrad           58
# Saab                   59
# MINI                   62
# Mercedes               64
# Buick                  71
# Infiniti               85
# Audi                   87
# Volvo                 103
# Subaru                105
# Jeep                  119
# Volkswagen            129
# ...

# %% [markdown]
# Question 4) (Instructio filtering)
#
# - Show all records where Engine Information Driveline is frontwheel

# %%
cars[cars['Engine Information.Driveline'].isin(['Front-wheel drive'])]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 1                   140                143               202
# 2                   140                143               202
# 12                  172                 63                87
# 44                  167                168               247
# 45                  167                168               247
# ...                 ...                ...               ...
# 5065                201                 33               219
# 5066                201                 33               219
# 5067                  3                253               201
# 5069                  3                253               201
# 5071                 13                253               201
#
#      Engine Information.Driveline  \
# 1               Front-wheel drive
# 2               Front-wheel drive
# 12              Front-wheel drive
# 44              Front-wheel drive
# 45              Front-wheel drive
# ...

# %% [markdown]
# Question 5) (Remove records)
#
# - Remove all the records where Horsepower is greater than or equal to 250
# - Remove all the records where Width is greater then 250

# %%
cars.head(2)
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# 1  6 Speed Automatic Select Shift                         22
#
#   Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                   Gasoline                            25
# ...

# %%
cars[~(cars['Engine Information.Engine Statistics.Horsepower']>=250)]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# 9                   147                 96                34
# ...                 ...                ...               ...
# 5062                201                 33               219
# 5063                201                 33               219
# 5064                201                 33               219
# 5065                201                 33               219
# 5066                201                 33               219
#
#      Engine Information.Driveline  \
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# 9                 All-wheel drive
# ...

# %%
cars.shape
# Out:
# (5076, 18)

# %%
cars[~(cars['Dimensions.Width']>250)]
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
cars.shape
# Out:
# (5076, 18)

# %% [markdown]
# Question 6) (Applying function in a column)
# - Increase all the values of 'Fuel Information.City mpg' column by 3

# %%
cars['Fuel Information.City mpg']
# Out:
# 0       18
# 1       22
# 2       21
# 3       21
# 4       21
#         ..
# 5071    18
# 5072    12
# 5073    12
# 5074    17
# 5075    17
# Name: Fuel Information.City mpg, Length: 5076, dtype: int64

# %%
cars['Fuel Information.City mpg'] = cars['Fuel Information.City mpg'].apply(lambda x:x+3)

# %%
cars['Fuel Information.City mpg']
# Out:
# 0       24
# 1       28
# 2       27
# 3       27
# 4       27
#         ..
# 5071    24
# 5072    18
# 5073    18
# 5074    23
# 5075    23
# Name: Fuel Information.City mpg, Length: 5076, dtype: int64
